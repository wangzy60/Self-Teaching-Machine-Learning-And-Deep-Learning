# %%
随机森林
弱分类器训练机制：对数据集的行和列同时进行有放回的随机采样，每次采样的维度和数量一样
，对采集到的K个相同大小的数据集分别训练，得到K个不同的弱学习器
弱分类器组合机制：分类投票，回归均值
adaBoost：
需要确定的参数：基分类器，损失函数，分类器组合方式，退出条件（预设的基分类器个数/退出的误差精度），激活函数
cart回归树：
树的生成控制元素：树的深度，叶子节点包含的数据量，树的预测精度……
每个叶子的取值如何确定：首先确定损失函数，其次要让每个叶子节点的所有数据经过损失函数计算之后的损失值最小，当损失函数是MSE时，取每个叶子节点的输出取其含有数据的平均值时，损失最小
每个分支的划分点如何确定：该划分点应该是当前所有可能的划分点中，根据损失函数和输出数据计算出来的损失值最小的那个
cart分类树（二叉树）：
树的生成控制元素：树的深度，叶子节点包含的数量，叶子节点的基尼系数是否达到预设值
每个叶子的取值如何确定：？
每个分支的划分点如何确定：这个划分点的基尼系数（P*(1-P)）最低
